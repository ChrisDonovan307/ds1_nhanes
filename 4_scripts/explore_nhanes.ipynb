# %%
# Check current working directory
# !pwd

# %%
# Move to ds1_nhanes directory permanently
# %cd /content/drive/MyDrive/ds1_nhanes/

# %% [markdown]
# ## Git

# %%
# !git clone https://github.com/ChrisDonovan307/ds1_nhanes.git

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'initial commit'

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
# !pwd

# %%
# Load daily recall 1 individual foods data
dat = pd.read_sas('nhanes_2021_2023/DR1IFF_L.xpt')
dat.info()

# %%
dat.info()
