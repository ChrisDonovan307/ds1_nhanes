# %% [markdown]
# # Terminal
#
# This is a jenky ass script for terminal functions that is really not ideal. But colab doesn't let you have a terminal because it feeds on frustration to survive. There is probably a better way to handle this, but hey

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/ds1_nhanes/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ds1_nhanes

# %%
# !git status
# Out:
# commit c9aab6ada40f0bffdf8f52088d18be65da5bf7ba (HEAD -> main, origin/main)
# Author: Christopher.Donovan <christopher.donovan@uvm.edu>
# Date:   Sun Apr 20 14:02:34 2025 -0400
#
#     updating Dockerfile and run script
#
# commit 1272803ded6ac491b9b21be1704168fe21c8c563
# Author: Chris Donovan <118745720+ChrisDonovan307@users.noreply.github.com>
# Date:   Sun Apr 20 13:37:57 2025 -0400
#
#     Update README.md
#
# commit 816fd9c8c59525edad0fbfb8fc28b5329f97f5fa
# Author: ChrisDonovan307 <ctudonovan@gmail.com>
# Date:   Sat Apr 19 23:22:11 2025 +0000
#
#     settled on cluster method, added demographic analysis
#
# commit 60cd27b5da6bdb77ecdc61b883388ebf3acae367
# Author: Christopher.Donovan <christopher.donovan@uvm.edu>
# Date:   Fri Apr 18 16:14:55 2025 -0400
#
#     fixing it again
#
# commit ba5555fba82f97313e771d0bb1a12a71be52e8ec
# Author: Christopher.Donovan <christopher.donovan@uvm.edu>
# Date:   Fri Apr 18 16:09:40 2025 -0400
#
#     fixing imputed csv, missing a biomarker
# ...
